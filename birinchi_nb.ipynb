# %% [markdown]
# <a href="https://colab.research.google.com/github/Asrorbek0002/glowing-system/blob/main/birinchi_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello ,Mohirdev")
# Out:
# Hello ,Mohirdev

# %% [markdown]
# # Heading
#  - [Kirish](mohirdev.uz)
#  - Muqqaddima

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import tensorflow as tf
import keras

# %%
tf.__version__
# Out:
# '2.17.1'

# %%
torch.__version__
# Out:
# '2.5.1+cu121'

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
! ls
# Out:
# sample_data

# %%
import pandas as pd
